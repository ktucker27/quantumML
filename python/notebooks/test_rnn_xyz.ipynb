# %%
# !pip install tensorflow==2.15
# !pip install qutip==4.7.6
# Out:
# Collecting tensorflow==2.15
#   Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow==2.15)
#   Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow==2.15)
#   Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15) (1.64.1)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow==2.15)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.16,>=2.15.0 (from tensorflow==2.15)
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.16,>=2.15.0 (from tensorflow==2.15)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15) (3.2.2)
# Downloading tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 2.6 MB/s eta 0:00:00
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.4 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.5 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 16.9 MB/s eta 0:00:00
# Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 9.6 MB/s eta 0:00:00
# Downloading wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: wrapt, tensorflow-estimator, ml-dtypes, keras, tensorboard, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.65 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0 ml-dtypes-0.2.0 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 wrapt-1.14.1
# Collecting qutip==4.7.6
#   Downloading qutip-4.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from qutip==4.7.6) (1.26.4)
# Collecting scipy<1.13.0,>=1.0 (from qutip==4.7.6)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from qutip==4.7.6) (24.1)
# Downloading qutip-4.7.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 81.1 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 16.3 MB/s eta 0:00:00
# Installing collected packages: scipy, qutip
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# osqp 0.6.7.post0 requires scipy!=1.12.0,>=0.13.2, but you have scipy 1.12.0 which is incompatible.
# Successfully installed qutip-4.7.6 scipy-1.12.0

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import scipy
from scipy import optimize
import os
import sys
import csv
import math
import time
import re
import pickle

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed
from tensorflow.keras import backend as K
#from keras.layers.preprocessing import preprocessing_utils

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
sys.path.append('/content/gdrive/MyDrive/git/quantumML/python/sdes')
import sde_solve
import sde_systems
import data_gen

sys.path.append('/content/gdrive/MyDrive/git/quantumML/python/systems')
import rabi_weak_meas

sys.path.append('/content/gdrive/MyDrive/git/quantumML/python/models')
import fusion
import flex
import train

sys.path.append('/content/gdrive/MyDrive/git/quantumML/python/models/test')
import test_fusion
# Out:
# /usr/local/lib/python3.10/dist-packages/qutip/__init__.py:66: UserWarning: The new version of Cython, (>= 3.0.0) is not supported.
#   warnings.warn(

# %%
import imp
imp.reload(fusion)
imp.reload(flex)
imp.reload(train)
imp.reload(sde_systems)
imp.reload(data_gen)
imp.reload(sde_solve)
imp.reload(test_fusion)
# Out:
# <module 'test_fusion' from '/content/gdrive/MyDrive/git/quantumML/python/models/test/test_fusion.py'>

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
import qutip as qt

# %% [markdown]
# # Run and test RNN vs. Liouv. vs. R2D vs. QuTip

# %%
sx0 = qt.tensor(qt.sigmax(), qt.identity(2))
sx1 = qt.tensor(qt.identity(2), qt.sigmax())
sy0 = qt.tensor(qt.sigmay(), qt.identity(2))
sy1 = qt.tensor(qt.identity(2), qt.sigmay())
sz0 = qt.tensor(qt.sigmaz(), qt.identity(2))
sz1 = qt.tensor(qt.identity(2), qt.sigmaz())
sm0 = qt.tensor(qt.sigmam(), qt.identity(2))
sm1 = qt.tensor(qt.identity(2), qt.sigmam())

qtmeas0 = [sx0, sy0, sz0]
qtmeas1 = [sx1, sy1, sz1]

sxx = qt.tensor(qt.sigmax(), qt.sigmax())
sxy = qt.tensor(qt.sigmax(), qt.sigmay())
sxz = qt.tensor(qt.sigmax(), qt.sigmaz())

syx = qt.tensor(qt.sigmay(), qt.sigmax())
syy = qt.tensor(qt.sigmay(), qt.sigmay())
syz = qt.tensor(qt.sigmay(), qt.sigmaz())

szx = qt.tensor(qt.sigmaz(), qt.sigmax())
szy = qt.tensor(qt.sigmaz(), qt.sigmay())
szz = qt.tensor(qt.sigmaz(), qt.sigmaz())

psi0 = qt.tensor(qt.basis(2,0), qt.basis(2,0))
qtrho0 = psi0*psi0.dag()

#qtopt = qt.Options()
#qtopt.method = 'euler-maruyama'

# %%
num_traj = 1
mint = 0.0
maxt = 4.0
deltat = 2**(-8)
tvec = np.arange(mint, maxt, deltat)

omega = 1.395
kappa = 0.83156
eta = 0.1469
gamma_s = 0.0
epsilons = [0.0, 0.5, 1.0]
num_eps = len(epsilons)
params = np.array([0.0,2.0*kappa,eta,gamma_s,0.0], dtype=np.double)

_, _, sz = sde_systems.paulis()
rho0 = sde_systems.get_init_rho(sz, sz, 0, 0)

# Make the RNN layer
lstm_size = 10
a_rnn_cell_real = tf.keras.layers.LSTMCell(lstm_size, kernel_initializer='zeros', recurrent_initializer='zeros', bias_initializer='zeros')
a_rnn_cell_imag = tf.keras.layers.LSTMCell(lstm_size, kernel_initializer='zeros', recurrent_initializer='zeros', bias_initializer='zeros')
b_rnn_cell_real = tf.keras.layers.LSTMCell(lstm_size, kernel_initializer='zeros', recurrent_initializer='zeros', bias_initializer='zeros')
b_rnn_cell_imag = tf.keras.layers.LSTMCell(lstm_size, kernel_initializer='zeros', recurrent_initializer='zeros', bias_initializer='zeros')

a_rnn_cell_real.trainable = False
a_rnn_cell_imag.trainable = False
b_rnn_cell_real.trainable = False
b_rnn_cell_imag.trainable = False

repeat_layer = tf.keras.layers.RepeatVector(tvec.shape[0])
#euler_cell = fusion.EulerRNNCell(rho0=tf.constant(rho0), maxt=1.5*deltat, deltat=deltat, params=params, num_traj=num_traj, input_param=4)
euler_cell = flex.EulerFlexRNNCell(a_rnn_cell_real, a_rnn_cell_imag, b_rnn_cell_real, b_rnn_cell_imag,
                                    rho0=tf.constant(rho0), maxt=1.5*deltat, deltat=deltat,
                                    params=params, num_traj=num_traj, input_param=[0,4], meas_param=2,
                                    project_rho=False, sim_noise=False)
rnn_layer = tf.keras.layers.RNN(euler_cell,
                                stateful=False,
                                return_sequences=True,
                                name='physical_layer')

# Setup input tensor
epsten = tf.constant(epsilons)
omegaten = omega*tf.ones([epsten.shape[0],1], tf.float32)
paramten = tf.concat([omegaten, epsten[:,tf.newaxis]], axis=1)
for meas_idx in range(3):
    meas_op = [meas_idx,meas_idx]
    meas_op0 = tf.one_hot([meas_op[0]], depth=3)*tf.ones([paramten.shape[0],3], tf.float32)
    meas_op1 = tf.one_hot([meas_op[1]], depth=3)*tf.ones([paramten.shape[0],3], tf.float32)
    meas_inputs = tf.concat([tf.cast(paramten, tf.float32), meas_op0, meas_op1], axis=1)
    r2d_meas_inputs = tf.concat([omegaten, tf.repeat(tf.constant(params[1:4], tf.float32)[tf.newaxis,:], omegaten.shape[0], axis=0), epsten[:,tf.newaxis], meas_op0, meas_op1], axis=1)
    if meas_idx == 0:
        traj_inputs = meas_inputs
        r2d_traj_inputs = r2d_meas_inputs
    else:
        traj_inputs = tf.concat([traj_inputs, meas_inputs], axis=0)
        r2d_traj_inputs = tf.concat([r2d_traj_inputs, r2d_meas_inputs], axis=0)
print('Input:')
print(traj_inputs)
print(r2d_traj_inputs)

r2d_rho0 = tf.repeat(rho0[tf.newaxis,...], traj_inputs.shape[0], axis=0)

# Run the layer
t0 = time.time()
print('Running Euler RNN layer...')
repeat_out = repeat_layer(traj_inputs)
probs = rnn_layer(repeat_out)
print(f'Done. Run time (s): {time.time() - t0}')
assert(tf.reduce_max(tf.abs(tf.math.imag(probs))) <= 1e-16)

# Run R2D
t0 = time.time()
print('Running run_model_2d...')
rhovec, ivec, _, _ = fusion.run_model_2d(r2d_rho0, r2d_traj_inputs, num_traj=traj_inputs.shape[0], mint=mint, maxt=maxt, deltat=deltat, sim_noise=False, comp_i=False)
print(f'Done. Run time (s): {time.time() - t0}')
r2d_probs = sde_systems.get_2d_probs(rhovec)
assert(tf.reduce_max(tf.abs(tf.math.imag(r2d_probs))) <= 1e-16)
r2d_probs = tf.math.real(r2d_probs)

for meas_idx in range(3):
    meas_op = [meas_idx,meas_idx]
    print(f'Checking measurement index {meas_idx}...')
    for epsidx, eps in enumerate(epsilons):
        print(f'Checking epsilon = {eps}...')

        # Run the Liouvillian
        liouv = sde_systems.RabiWeakMeasSDE.get_liouv(omega, 2.0*kappa, [eps], 2, meas_op)
        _, probs_truth = sde_systems.get_2d_probs_truth(liouv, rho0, deltat, maxt - deltat*0.5)

        # Compare all probabilities
        assert(tf.reduce_max(tf.abs(tf.math.imag(probs_truth))) <= 1e-14)
        mses = tf.reduce_mean(tf.pow(probs[meas_idx*num_eps + epsidx, :-1, :42] - tf.math.real(probs_truth[1:,:]), 2.0), axis=[0])
        max_mse = tf.reduce_max(mses)
        print(f'Liouv MSE: {max_mse}, mse shape = {mses.shape}')
        assert(max_mse <= 2e-6)

        # Run QuTip
        H = 0.5*omega*(sx0 + sx1) + eps*szz
        #result = qt.mesolve(H, psi0, tvec, [np.sqrt(kappa) * qtmeas0[meas_idx], np.sqrt(kappa) * qtmeas1[meas_idx], np.sqrt(gamma_s)*sm0, np.sqrt(gamma_s)*sm1], [sx0, sx1, sy0, sy1, sz0, sz1], options=qtopt)
        result = qt.smesolve(H, qtrho0, tvec,
                     #c_ops=[np.sqrt(1.0 - 0.5*eta)*np.sqrt(kappa) * sx0, np.sqrt(1.0 - 0.5*eta)*np.sqrt(kappa) * sy1, np.sqrt(gamma_s)*sm0, np.sqrt(gamma_s)*sm1],
                     c_ops=[np.sqrt(kappa) * qtmeas0[meas_idx], np.sqrt(kappa) * qtmeas1[meas_idx], np.sqrt(gamma_s)*sm0, np.sqrt(gamma_s)*sm1],
                     #sc_ops=[np.sqrt(0.5*eta*kappa) * sx0, np.sqrt(0.5*eta*kappa) * sy1],
                     e_ops=[sx0, sx1, sy0, sy1, sz0, sz1],
                     ntraj=1,
                     #dW_factors=[1,1],
                     solver='euler-maruyama',
                     store_measurement=False)

        # Compare all single qubit probabilities
        qtmses = np.zeros(len(result.expect))
        for ii in range(len(result.expect)):
            qtmses[ii] = tf.reduce_mean(tf.square(probs[meas_idx*num_eps + epsidx,:-1,ii] - 0.5*(result.expect[ii][1:] + 1.0)))
        max_qtmse = np.max(qtmses)
        print(f'Max QuTip prob MSE:', max_qtmse, f'(out of {len(result.expect)})')
        assert(max_qtmse <= 1.0e-14)

        # Compare R2D probabilities
        r2dmses = tf.reduce_mean(tf.pow(probs[meas_idx*num_eps + epsidx, :-1, :42] - r2d_probs[meas_idx*num_eps + epsidx, 1:, :42], 2.0), axis=[0])
        max_r2dmse = tf.reduce_max(r2dmses)
        print(f'R2D MSE: {max_r2dmse}, mse shape = {r2dmses.shape}')
        assert(max_r2dmse <= 1.0e-14)

        print(' ')
# Out:
# Input:
# tf.Tensor(
# [[1.395 0.    1.    0.    0.    1.    0.    0.   ]
#  [1.395 0.5   1.    0.    0.    1.    0.    0.   ]
#  [1.395 1.    1.    0.    0.    1.    0.    0.   ]
#  [1.395 0.    0.    1.    0.    0.    1.    0.   ]
#  [1.395 0.5   0.    1.    0.    0.    1.    0.   ]
#  [1.395 1.    0.    1.    0.    0.    1.    0.   ]
#  [1.395 0.    0.    0.    1.    0.    0.    1.   ]
#  [1.395 0.5   0.    0.    1.    0.    0.    1.   ]
#  [1.395 1.    0.    0.    1.    0.    0.    1.   ]], shape=(9, 8), dtype=float32)
# tf.Tensor(
# [[1.395   1.66312 0.1469  0.      0.      1.      0.      0.      1.
#   0.      0.     ]
#  [1.395   1.66312 0.1469  0.      0.5     1.      0.      0.      1.
#   0.      0.     ]
#  [1.395   1.66312 0.1469  0.      1.      1.      0.      0.      1.
#   0.      0.     ]
#  [1.395   1.66312 0.1469  0.      0.      0.      1.      0.      0.
#   1.      0.     ]
#  [1.395   1.66312 0.1469  0.      0.5     0.      1.      0.      0.
#   1.      0.     ]
#  [1.395   1.66312 0.1469  0.      1.      0.      1.      0.      0.
#   1.      0.     ]
#  [1.395   1.66312 0.1469  0.      0.      0.      0.      1.      0.
#   0.      1.     ]
#  [1.395   1.66312 0.1469  0.      0.5     0.      0.      1.      0.
#   0.      1.     ]
#  [1.395   1.66312 0.1469  0.      1.      0.      0.      1.      0.
#   0.      1.     ]], shape=(9, 11), dtype=float32)
# Running Euler RNN layer...
# l t =  tf.Tensor(0.0, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0, shape=(), dtype=float32)
# l t =  tf.Tensor(0.00390625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0078125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.01171875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.015625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.01953125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0234375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.02734375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.03125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.03515625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0390625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.04296875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.046875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.05078125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0546875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.05859375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.06640625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0703125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.07421875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.078125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.08203125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.0859375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.08984375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.09375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.09765625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1015625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.10546875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.109375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.11328125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1171875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.12109375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.12890625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1328125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.13671875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.140625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.14453125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1484375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.15234375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.15625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.16015625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1640625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.16796875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.171875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.17578125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1796875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.18359375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.19140625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.1953125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.19921875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.203125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.20703125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.2109375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.21484375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.21875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.22265625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.2265625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.23046875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.234375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.23828125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.2421875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.24609375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.25, shape=(), dtype=float32)
# l t =  tf.Tensor(0.25390625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.2578125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.26171875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.265625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.26953125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.2734375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.27734375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.28125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.28515625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.2890625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.29296875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.296875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.30078125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3046875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.30859375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.31640625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3203125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.32421875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.328125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.33203125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3359375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.33984375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.34375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.34765625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3515625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.35546875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.359375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.36328125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3671875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.37109375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.37890625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3828125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.38671875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.390625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.39453125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.3984375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.40234375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.40625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.41015625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4140625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.41796875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.421875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.42578125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4296875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.43359375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.44140625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4453125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.44921875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.453125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.45703125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4609375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.46484375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.46875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.47265625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4765625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.48046875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.484375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.48828125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.4921875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.49609375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5, shape=(), dtype=float32)
# l t =  tf.Tensor(0.50390625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5078125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.51171875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.515625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.51953125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5234375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.52734375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.53125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.53515625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5390625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.54296875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.546875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.55078125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5546875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.55859375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.56640625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5703125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.57421875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.578125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.58203125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.5859375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.58984375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.59375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.59765625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.6015625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.60546875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.609375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.61328125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.6171875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.62109375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.62890625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.6328125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.63671875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.640625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.64453125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.6484375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.65234375, shape=(), dtype=float32)
# l t =  tf.Tensor(0.65625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.66015625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.6640625, shape=(), dtype=float32)
# l t =  tf.Tensor(0.66796875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.671875, shape=(), dtype=float32)
# l t =  tf.Tensor(0.67578125, shape=(), dtype=float32)
# l t =  tf.Tensor(0.6796875, shape=(), dtype=float32)
# l t =  tf.Tensor(0
# l t =  2.96875
# l t =  3.0078125
# l t =  3.046875
# l t =  3.0859375
# l t =  3.125
# l t =  3.1640625
# l t =  3.203125
# l t =  3.2421875
# l t =  3.28125
# l t =  3.3203125
# l t =  3.359375
# l t =  3.3984375
# l t =  3.4375
# l t =  3.4765625
# l t =  3.515625
# l t =  3.5546875
# l t =  3.59375
# l t =  3.6328125
# l t =  3.671875
# l t =  3.7109375
# l t =  3.75
# l t =  3.7890625
# l t =  3.828125
# l t =  3.8671875
# l t =  3.90625
# l t =  3.9453125
# l t =  3.984375
# Rho done
# Done. Run time (s): 313.906777381897
# Checking measurement index 0...
# Checking epsilon = 0.0...
# Liouv MSE: 4.2145432471737726e-07, mse shape = (42,)
# Total run time:   0.02s
# Max QuTip prob MSE: 3.240025916245379e-17 (out of 6)
# R2D MSE: 4.86308732150698e-19, mse shape = (42,)
#
# Checking epsilon = 0.5...
# Liouv MSE: 4.14955526937175e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 2.3586786411722628e-17 (out of 6)
# R2D MSE: 0.0, mse shape = (42,)
#
# Checking epsilon = 1.0...
# Liouv MSE: 3.9910630868472654e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 1.3010518724961954e-17 (out of 6)
# R2D MSE: 0.0, mse shape = (42,)
#
# Checking measurement index 1...
# Checking epsilon = 0.0...
# Liouv MSE: 5.372654585541321e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 7.111116696810624e-17 (out of 6)
# R2D MSE: 1.3975853658283913e-19, mse shape = (42,)
#
# Checking epsilon = 0.5...
# Liouv MSE: 5.235738102627035e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 3.6940703497244626e-17 (out of 6)
# R2D MSE: 0.0, mse shape = (42,)
#
# Checking epsilon = 1.0...
# Liouv MSE: 4.776378727774777e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 1.2555510741523033e-17 (out of 6)
# R2D MSE: 0.0, mse shape = (42,)
#
# Checking measurement index 2...
# Checking epsilon = 0.0...
# Liouv MSE: 4.606335986260348e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 2.1807843408360733e-16 (out of 6)
# R2D MSE: 8.625512872474039e-19, mse shape = (42,)
#
# Checking epsilon = 0.5...
# Liouv MSE: 3.466019111679727e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 1.4655724213927736e-16 (out of 6)
# R2D MSE: 0.0, mse shape = (42,)
#
# Checking epsilon = 1.0...
# Liouv MSE: 2.8374233918927336e-07, mse shape = (42,)
# Total run time:   0.01s
# Max QuTip prob MSE: 5.996506864276634e-17 (out of 6)
# R2D MSE: 0.0, mse shape = (42,)

# %%
rnntvec = tf.concat([tvec[1:], [tvec[-1] + deltat]], axis=0)
print(tvec.shape, rnntvec.shape)
print(tvec[-1], rnntvec[-1])
# Out:
# (1024,) (1024,)
# 3.99609375 tf.Tensor(4.0, shape=(), dtype=float64)

# %%
print(meas_idx, epsidx)
# Out:
# 2 2

# %%
plt.figure(figsize=(16,12))
print('Liouv:')
for qidx in range(2):
  plt.subplot(3,2,qidx+1)
  for prob_idx in range(3):
    plt.plot(rnntvec, probs[meas_idx*num_eps + epsidx, :, 2*prob_idx + qidx], label=f'RNN {prob_idx}')
    plt.plot(tvec, probs_truth[:,2*prob_idx + qidx], '--', label=f'Liouv {prob_idx}')
    print(2*prob_idx + qidx, tf.reduce_mean(tf.square(probs[meas_idx*num_eps + epsidx, :-1, 2*prob_idx + qidx] - tf.math.real(probs_truth)[1:,2*prob_idx + qidx])))
  plt.legend()
  plt.grid();

print('\nQuTip:')
for qidx in range(2):
  plt.subplot(3,2,2+qidx+1)
  for prob_idx in range(3):
    plt.plot(rnntvec, probs[meas_idx*num_eps + epsidx, :, 2*prob_idx + qidx], label=f'RNN {prob_idx}')
    plt.plot(tvec, 0.5*(result.expect[2*prob_idx+qidx] + 1.0), '--', label=f'qutip {prob_idx}')
    print(2*prob_idx + qidx, tf.reduce_mean(tf.square(probs[meas_idx*num_eps + epsidx, :-1, 2*prob_idx + qidx] - 0.5*(result.expect[2*prob_idx+qidx][1:] + 1.0))))
  plt.legend()
  plt.grid();

print('\nR2D:')
for qidx in range(2):
  plt.subplot(3,2,4+qidx+1)
  for prob_idx in range(3):
    plt.plot(rnntvec, probs[meas_idx*num_eps + epsidx, :, 2*prob_idx + qidx], label=f'RNN {prob_idx}')
    plt.plot(tvec, r2d_probs[meas_idx*num_eps + epsidx, :, 2*prob_idx + qidx], '--', label=f'R2D {prob_idx}')
    print(2*prob_idx + qidx, tf.reduce_mean(tf.square(probs[meas_idx*num_eps + epsidx, :-1, 2*prob_idx + qidx] - r2d_probs[meas_idx*num_eps + epsidx, 1:, 2*prob_idx + qidx])))
  plt.legend()
  plt.grid();
# Out:
# Liouv:
# 0 tf.Tensor(8.677326011423417e-08, shape=(), dtype=float64)
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# 2 tf.Tensor(1.4878328964090966e-07, shape=(), dtype=float64)
# 4 tf.Tensor(5.983926577386582e-08, shape=(), dtype=float64)
# 1 tf.Tensor(8.677326011422588e-08, shape=(), dtype=float64)
# 3 tf.Tensor(1.4878328964088319e-07, shape=(), dtype=float64)
# 5 tf.Tensor(5.983926577382865e-08, shape=(), dtype=float64)
#
# QuTip:
# 0 tf.Tensor(7.615471435932874e-18, shape=(), dtype=float64)
# 2 tf.Tensor(1.0670234062610872e-17, shape=(), dtype=float64)
# 4 tf.Tensor(5.996506864276634e-17, shape=(), dtype=float64)
# 1 tf.Tensor(7.615471425337867e-18, shape=(), dtype=float64)
# 3 tf.Tensor(1.0670234052722486e-17, shape=(), dtype=float64)
# 5 tf.Tensor(5.996506851389318e-17, shape=(), dtype=float64)
#
# R2D:
# 0 tf.Tensor(0.0, shape=(), dtype=float64)
# 2 tf.Tensor(0.0, shape=(), dtype=float64)
# 4 tf.Tensor(0.0, shape=(), dtype=float64)
# 1 tf.Tensor(0.0, shape=(), dtype=float64)
# 3 tf.Tensor(0.0, shape=(), dtype=float64)
# 5 tf.Tensor(0.0, shape=(), dtype=float64)

# %%
qtmses = np.zeros(len(result.expect))
for ii in range(len(result.expect)):
    print(ii, tf.reduce_mean(tf.square(tf.math.real(probs_truth)[1:,ii] - probs[meas_idx*num_eps + epsidx,:-1,ii])))
    print(ii, tf.reduce_mean(tf.square(tf.math.real(probs_truth)[:,ii] - 0.5*(result.expect[ii] + 1.0))))
max_qtmse = np.max(qtmses)
# Out:
# 0 tf.Tensor(8.677326011423417e-08, shape=(), dtype=float64)
# 0 tf.Tensor(8.668943567281927e-08, shape=(), dtype=float64)
# 1 tf.Tensor(8.677326011422588e-08, shape=(), dtype=float64)
# 1 tf.Tensor(8.668943567281069e-08, shape=(), dtype=float64)
# 2 tf.Tensor(1.4878328964090966e-07, shape=(), dtype=float64)
# 2 tf.Tensor(1.4864020781709636e-07, shape=(), dtype=float64)
# 3 tf.Tensor(1.4878328964088319e-07, shape=(), dtype=float64)
# 3 tf.Tensor(1.4864020781707005e-07, shape=(), dtype=float64)
# 4 tf.Tensor(5.983926577386582e-08, shape=(), dtype=float64)
# 4 tf.Tensor(5.978415526904679e-08, shape=(), dtype=float64)
# 5 tf.Tensor(5.983926577382865e-08, shape=(), dtype=float64)
# 5 tf.Tensor(5.978415526900624e-08, shape=(), dtype=float64)

# %%
tf.math.real(probs_truth[:10,0])
# Out:
# <tf.Tensor: shape=(10,), dtype=float64, numpy=
# array([0.5       , 0.5000106 , 0.5000422 , 0.50009454, 0.50016733,
#        0.50026029, 0.50037314, 0.50050559, 0.50065738, 0.50082821])>

# %%
0.5*(result.expect[0][:10] + 1.0)
# Out:
# array([0.5       , 0.5       , 0.50002129, 0.50006358, 0.50012661,
#        0.50021009, 0.50031374, 0.50043729, 0.50058045, 0.50074293])

# %%
probs[meas_idx*num_eps + epsidx,:10,0]
# Out:
# <tf.Tensor: shape=(10,), dtype=float64, numpy=
# array([0.5       , 0.50002129, 0.50006358, 0.50012661, 0.50021009,
#        0.50031374, 0.50043729, 0.50058045, 0.50074293, 0.50092446])>

# %% [markdown]
# ## Second Order Probabilities

# %%
plt.figure(figsize=(16,12))
pltidx = 0
for rowidx in range(3):
  sum = 0.0
  for colidx in range(4):
    plt.subplot(3,4,pltidx+1)
    plt.plot(rnntvec, probs[meas_idx*num_eps + epsidx,:,6+pltidx])
    sum += probs[meas_idx*num_eps + epsidx,-1,6+pltidx]
    plt.plot(tvec, probs_truth[:,6+pltidx])
    plt.grid();
    plt.ylim([0,1])
    pltidx += 1
  print(sum)
# Out:
# tf.Tensor(1.0, shape=(), dtype=float64)
# tf.Tensor(1.0000000000000002, shape=(), dtype=float64)
# tf.Tensor(1.0000000000000004, shape=(), dtype=float64)

# %%
plt.figure(figsize=(16,12))
pltidx = 0
for rowidx in range(3):
  sum = 0.0
  for colidx in range(4):
    plt.subplot(3,4,pltidx+1)
    plt.plot(rnntvec, probs[meas_idx*num_eps + epsidx,:,6+12+pltidx])
    sum += probs[meas_idx*num_eps + epsidx,-1,6+12+pltidx]
    plt.plot(tvec, probs_truth[:,6+12+pltidx])
    plt.grid();
    plt.ylim([0,1])
    pltidx += 1
  print(sum)
# Out:
# tf.Tensor(1.0000000000000002, shape=(), dtype=float64)
# tf.Tensor(1.0000000000000002, shape=(), dtype=float64)
# tf.Tensor(1.0000000000000004, shape=(), dtype=float64)

# %%
plt.figure(figsize=(16,12))
pltidx = 0
for rowidx in range(3):
  sum = 0.0
  for colidx in range(4):
    plt.subplot(3,4,pltidx+1)
    plt.plot(rnntvec, probs[meas_idx*num_eps + epsidx,:,6+12+12+pltidx])
    sum += probs[meas_idx*num_eps + epsidx,-1,6+12+12+pltidx]
    plt.plot(tvec, probs_truth[:,6+12+12+pltidx])
    plt.grid();
    plt.ylim([0,1])
    pltidx += 1
  print(sum)
# Out:
# tf.Tensor(1.0000000000000002, shape=(), dtype=float64)
# tf.Tensor(1.0000000000000004, shape=(), dtype=float64)
# tf.Tensor(1.0000000000000004, shape=(), dtype=float64)

# %%
print(tf.reduce_min(probs[:,:,:42]), tf.reduce_max(probs[:,:,:42]))
# Out:
# tf.Tensor(0.0, shape=(), dtype=float64) tf.Tensor(1.0, shape=(), dtype=float64)
